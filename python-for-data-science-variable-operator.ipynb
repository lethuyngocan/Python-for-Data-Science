# %% [markdown]
# <a href="https://www.kaggle.com/code/ankumagawa/python-for-data-science-variable-operator?scriptVersionId=136522223" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 1) Variable:

# %%
x=3
print(type(x))
# Out:
# <class 'int'>

# %%
x=5.7
print(type(x))
# Out:
# <class 'float'>

# %%
y= 556.32
print(type(y))
# Out:
# <class 'float'>

# %% [markdown]
# %whos list all the data we have in the data

# %%
# %whos
# Out:
# Variable    Type      Data/Info
# -------------------------------
# dirname     str       /kaggle/input
# filenames   list      n=0
# np          module    <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# os          module    <module 'os' from '/opt/c<...>da/lib/python3.10/os.py'>
# pd          module    <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# x           float     5.7
# y           float     556.32

# %%
a,b,c,d= 3,5,7.8,-3
# %whos
# Out:
# Variable    Type      Data/Info
# -------------------------------
# a           int       3
# b           int       5
# c           float     7.8
# d           int       -3
# dirname     str       /kaggle/input
# filenames   list      n=0
# np          module    <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# os          module    <module 'os' from '/opt/c<...>da/lib/python3.10/os.py'>
# pd          module    <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# x           float     5.7
# y           float     556.32

# %%
k='summer'
print(type(k))
# Out:
# <class 'str'>

# %%
# %whos
# Out:
# Variable    Type      Data/Info
# -------------------------------
# a           int       3
# b           int       5
# c           float     7.8
# d           int       -3
# dirname     str       /kaggle/input
# filenames   list      n=0
# k           str       summer
# np          module    <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# os          module    <module 'os' from '/opt/c<...>da/lib/python3.10/os.py'>
# pd          module    <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# x           float     5.7
# y           float     556.32

# %%
h=2+4j
print(type(h))
# Out:
# <class 'complex'>

# %%
# %whos
# Out:
# Variable    Type       Data/Info
# --------------------------------
# a           int        3
# b           int        5
# c           float      7.8
# d           int        -3
# dirname     str        /kaggle/input
# filenames   list       n=0
# h           complex    (2+4j)
# k           str        summer
# np          module     <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# os          module     <module 'os' from '/opt/c<...>da/lib/python3.10/os.py'>
# pd          module     <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# x           float      5.7
# y           float      556.32

# %% [markdown]
# ## 2. Operators:

# %%
sumab=a+b

# %%
print(sumab), 
print('type of the sum is', type(sumab))
# Out:
# 8
# type of the sum is <class 'int'>

# %%
l=((a+c)**3)/4
l
# Out:
# 314.92800000000005

# %% [markdown]
# the operator does not only work with numeric data but also with alphabec data

# %%
s1= 'hello'
s2= 'word'
s=s1+s2
s
# Out:
# 'helloword'

# %%
10//3 #Floor division
# Out:
# 3

# %%
10%3 #Modulus
# Out:
# 1

# %%
10**3 #Exponentiation
# Out:
# 1000

# %% [markdown]
# ## 3) Bool:

# %%
v=True
n=True
m=False

# %%
# %whos
# Out:
# Variable    Type       Data/Info
# --------------------------------
# a           int        3
# b           int        5
# c           float      7.8
# d           int        -3
# dirname     str        /kaggle/input
# filenames   list       n=0
# h           complex    (2+4j)
# k           str        summer
# l           float      314.92800000000005
# m           bool       False
# n           bool       True
# np          module     <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# os          module     <module 'os' from '/opt/c<...>da/lib/python3.10/os.py'>
# pd          module     <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# s           str        helloword
# s1          str        hello
# s2          str        word
# sumab       int        8
# v           bool       True
# x           float      5.7
# y           float      556.32

# %%
print(m and n)
print(v and m)
print(v and n)
# Out:
# False
# False
# True

# %%
print(m or n)
print(v or m)
print(v or n)
# Out:
# True
# True
# True

# %%
print(not(m))
print(not(v))
print(not(n))
# Out:
# True
# False
# False

# %%
not((m or n) and (v and m))
# Out:
# True

# %% [markdown]
# ## 4) Comparision:

# %%
print( 2<4) #Less than
print(2>4) # Greater
print(2==4) #Equal
print(2!=4) #Not equal
print(2<=4) # Less than or equal to
print(2>=4) # Larger or equal to
# Out:
# True
# False
# False
# True
# True
# False

# %%
x= 4
y=9
z=8.3
r=-3

# %%
(x<y) and (z<y) or (r==x) # true and true or false ->true
# Out:
# True

# %%
(x<y) and (r==x) or (z>y) # true and false or false  -> false
# Out:
# False
